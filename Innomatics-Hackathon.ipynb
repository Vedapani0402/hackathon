# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("uber_rides_data.xlsx - sample_train.csv")

# %%
data
# Out:
#          ride_id  fare_amount          pickup_datetime  pickup_longitude  \
# 0       24238194          7.5  2015-05-07 19:52:06 UTC        -73.999817
# 1       27835199          7.7  2009-07-17 20:04:56 UTC        -73.994355
# 2       44984355         12.9  2009-08-24 21:45:00 UTC        -74.005043
# 3       25894730          5.3  2009-06-26 08:22:21 UTC        -73.976124
# 4       17610152         16.0  2014-08-28 17:47:00 UTC        -73.925023
# ...          ...          ...                      ...               ...
# 199995  42598914          3.0  2012-10-28 10:49:00 UTC        -73.987042
# 199996  16382965          7.5  2014-03-14 01:09:00 UTC        -73.984722
# 199997  27804658         30.9  2009-06-29 00:42:00 UTC        -73.986017
# 199998  20259894         14.5  2015-05-20 14:56:25 UTC        -73.997124
# 199999  11951496         14.1  2010-05-15 04:08:00 UTC        -73.984395
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# ...

# %%
data.dtypes
# Out:
# ride_id                int64
# fare_amount          float64
# pickup_datetime       object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# dtype: object

# %%
data['dropoff_longitude'].isnull().sum()
# Out:
# 1

# %%
data.isnull().sum()
# Out:
# ride_id              0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# dtype: int64

# %%
data1=data.dropna()

# %%
data1['fare_amount'].mean()
# Out:
# 11.359891549457748

# %%
from math import radians, cos, sin, asin, sqrt

def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance in kilometers between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 6371 # Radius of earth in kilometers. Use 3956 for miles. Determines return value units.
    return c * r

# %%
data1['hdistance']=data1.apply(lambda x: haversine(x['pickup_longitude'],x['pickup_latitude'],x['dropoff_longitude'],x['dropoff_latitude']),axis=1)
# Out:
# C:\Users\gnvsa\AppData\Local\Temp\ipykernel_28768\3814504204.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['hdistance']=data1.apply(lambda x: haversine(x['pickup_longitude'],x['pickup_latitude'],x['dropoff_longitude'],x['dropoff_latitude']),axis=1)

# %%
data1['hdistance'].median()
# Out:
# 2.1209923961833708

# %%
data1['hdistance'].max()
# Out:
# 16409.239135313164

# %%
count=np.where(data1['hdistance']==0)

# %%
len(count[0])
# Out:
# 5632

# %%
df=data1.loc[data1['hdistance']==0]
df
# Out:
#          ride_id  fare_amount          pickup_datetime  pickup_longitude  \
# 5       44470845          4.9  2011-02-12 02:27:09 UTC        -73.969019
# 7       44195482          2.5  2012-12-11 13:52:00 UTC          0.000000
# 11       6379048          8.5  2011-05-23 22:15:00 UTC          0.000000
# 48      22405517         56.8  2013-01-03 22:24:41 UTC        -73.993498
# 65      21993993          6.0  2014-05-05 19:27:00 UTC          0.000000
# ...          ...          ...                      ...               ...
# 199880  35013970          6.5  2014-02-22 06:45:46 UTC          0.000000
# 199883  44115598         12.5  2012-09-10 17:39:00 UTC          0.000000
# 199917  45368488          4.5  2013-06-24 22:17:43 UTC        -73.793768
# 199932  46517645         24.9  2011-03-22 13:59:00 UTC        -73.974618
# 199963  50075618         39.0  2012-09-22 07:46:01 UTC          0.000000
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# ...

# %%
df['fare_amount'].mean()
# Out:
# 11.585317826704546

# %%
data1['fare_amount'].max()
# Out:
# 499.0

# %%
data1.loc[data1['fare_amount']==499.0]
# Out:
#          ride_id  fare_amount          pickup_datetime  pickup_longitude  \
# 170081  51151143        499.0  2011-04-10 04:10:00 UTC        -73.968377
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 170081        40.764602         -73.968368           40.7646                1
#
#         hdistance
# 170081    0.00079

# %%
data1['pickup_datetime'] = pd.to_datetime(data1['pickup_datetime'])

# Extract day, month, and year values into separate columns
data1['day'] = data1['pickup_datetime'].dt.day
data1['month'] = data1['pickup_datetime'].dt.month
data1['year'] = data1['pickup_datetime'].dt.year
# Out:
# C:\Users\gnvsa\AppData\Local\Temp\ipykernel_28768\2514658834.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['pickup_datetime'] = pd.to_datetime(data1['pickup_datetime'])
# C:\Users\gnvsa\AppData\Local\Temp\ipykernel_28768\2514658834.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['day'] = data1['pickup_datetime'].dt.day
# C:\Users\gnvsa\AppData\Local\Temp\ipykernel_28768\2514658834.py:5: SettingWithCopyWarning:
# ...

# %%
data1
# Out:
#          ride_id  fare_amount           pickup_datetime  pickup_longitude  \
# 0       24238194          7.5 2015-05-07 19:52:06+00:00        -73.999817
# 1       27835199          7.7 2009-07-17 20:04:56+00:00        -73.994355
# 2       44984355         12.9 2009-08-24 21:45:00+00:00        -74.005043
# 3       25894730          5.3 2009-06-26 08:22:21+00:00        -73.976124
# 4       17610152         16.0 2014-08-28 17:47:00+00:00        -73.925023
# ...          ...          ...                       ...               ...
# 199995  42598914          3.0 2012-10-28 10:49:00+00:00        -73.987042
# 199996  16382965          7.5 2014-03-14 01:09:00+00:00        -73.984722
# 199997  27804658         30.9 2009-06-29 00:42:00+00:00        -73.986017
# 199998  20259894         14.5 2015-05-20 14:56:25+00:00        -73.997124
# 199999  11951496         14.1 2010-05-15 04:08:00+00:00        -73.984395
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# ...

# %%
data1.loc[data1['year']==2014]
# Out:
#          ride_id  fare_amount           pickup_datetime  pickup_longitude  \
# 4       17610152        16.00 2014-08-28 17:47:00+00:00        -73.925023
# 6       48725865        24.50 2014-10-12 07:04:00+00:00        -73.961447
# 20      55085966        10.50 2014-02-18 14:26:00+00:00        -73.980022
# 26      38755863         5.00 2014-01-21 06:55:00+00:00        -73.957802
# 34      19277743        39.50 2014-06-04 06:49:00+00:00        -73.788080
# ...          ...          ...                       ...               ...
# 199979   9699676         6.00 2014-06-08 21:38:43+00:00        -73.975209
# 199981  21553740         9.00 2014-06-02 21:51:50+00:00        -73.980445
# 199982  13096190        57.33 2014-08-06 11:06:06+00:00        -73.969204
# 199994   3189201        12.00 2014-01-31 14:42:00+00:00        -73.983070
# 199996  16382965         7.50 2014-03-14 01:09:00+00:00        -73.984722
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# ...

# %%
data1["Quarter"] = data1['pickup_datetime'].dt.quarter
# Out:
# C:\Users\gnvsa\AppData\Local\Temp\ipykernel_28768\2059691354.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["Quarter"] = data1['pickup_datetime'].dt.quarter

# %%
data1.loc[(data1['year']==2014) & (data1['Quarter']==1)]
# Out:
#          ride_id  fare_amount           pickup_datetime  pickup_longitude  \
# 20      55085966         10.5 2014-02-18 14:26:00+00:00        -73.980022
# 26      38755863          5.0 2014-01-21 06:55:00+00:00        -73.957802
# 39      38703737         29.0 2014-02-13 17:57:00+00:00        -73.992600
# 46      37192633         17.0 2014-01-16 14:58:09+00:00        -73.993900
# 100     29350780          9.0 2014-02-19 18:02:00+00:00        -73.958280
# ...          ...          ...                       ...               ...
# 199931  28516870         11.0 2014-01-08 20:52:14+00:00        -74.005809
# 199943   9784541         10.0 2014-02-13 18:06:00+00:00        -73.970460
# 199964   4642171          6.0 2014-02-25 13:37:00+00:00        -73.991367
# 199994   3189201         12.0 2014-01-31 14:42:00+00:00        -73.983070
# 199996  16382965          7.5 2014-03-14 01:09:00+00:00        -73.984722
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# ...

# %%
data1['week_day']=data1['pickup_datetime'].dt.dayofweek
# Out:
# C:\Users\gnvsa\AppData\Local\Temp\ipykernel_28768\563950010.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['week_day']=data1['pickup_datetime'].dt.dayofweek

# %%
d=data1.loc[(data1['month']==9) & (data1['year']==2010)]

# %%
d.groupby(d['week_day']).count()
# Out:
#           ride_id  fare_amount  pickup_datetime  pickup_longitude  \
# week_day
# 0             265          265              265               265
# 1             322          322              322               322
# 2             391          391              391               391
# 3             457          457              457               457
# 4             354          354              354               354
# 5             362          362              362               362
# 6             331          331              331               331
#
#           pickup_latitude  dropoff_longitude  dropoff_latitude  \
# week_day
# 0                     265                265               265
# 1                     322                322               322
# 2                     391                391               391
# 3                     457                457               457
# 4                     354                354               354
# ...

# %% [markdown]
# ### Train-test-Split

# %%
from sklearn.model_selection import train_test_split
x=data1[['passenger_count', 'hdistance', 'week_day']]
y=data1['fare_amount']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=100)

# %% [markdown]
# #### Pre-processing (Scaling and Encodiing)

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder , StandardScaler
onc=OneHotEncoder(drop='first',handle_unknown='ignore')
onc.fit(x_train[['week_day']])
x_train_cat=pd.DataFrame(onc.transform(x_train[['week_day']]).toarray(), columns=onc.get_feature_names())
x_test_cat=pd.DataFrame(onc.transform(x_test[['week_day']]).toarray(), columns=onc.get_feature_names())
# Out:
# C:\Users\gnvsa\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\gnvsa\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
ncols=['passenger_count', 'hdistance']
scaler = StandardScaler()
scaler.fit(x_train[ncols])
x_train_std = pd.DataFrame(scaler.transform(x_train[ncols]),columns=x_train[ncols].columns)
x_test_std = pd.DataFrame(scaler.transform(x_test[ncols]),columns=x_train[ncols].columns)

# %%
x_train_con=pd.concat((x_train_cat,x_train_std),axis=1)
x_test_con=pd.concat((x_test_cat,x_test_std),axis=1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ### Model Training

# %% [markdown]
# #### Linear Regression

# %%
linreg = LinearRegression()
model_l=linreg.fit(x_train_con, y_train)

# %%
r_sqr = model_l.score(x_test_con, y_test)
n= x_test.shape[1]
p = len(y_test)
adjusted_r = 1 - (1 - r_sqr) * (p - 1) / (n - p-  1)
adjusted_r
# Out:
# 1.9990068319211178

# %% [markdown]
# #### Random Forest Regressor

# %%
rfr = RandomForestRegressor()
model_r=rfr.fit(x_train_con, y_train)

# %%
r_sqr = model_r.score(x_test_con, y_test)
n= x_test.shape[1]
p = len(y_test)
adjusted_r = 1 - (1 - r_sqr) * (p - 1) / (n - p-  1)
adjusted_r
# Out:
# 1.3575840013659572
